# %% [markdown]
# <a href="https://colab.research.google.com/github/itsdakshjain/CodeCompanions/blob/main/collab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
checking 1 (checking 3)

# %%
checking 2
